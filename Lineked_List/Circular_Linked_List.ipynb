# %%
class Node:
    def __init__(self,data):
        self.data =data
        self.addr =None
class Circular_Linked_List:
    def __init__(self):
        self.head =None
    
    def insert_at_last(self,val):
        newNode =Node(val)
        if self.head is None:
            self.head =newNode
            newNode.addr =newNode
        else:
            temp =self.head
            while temp.addr != self.head:
                temp =temp.addr
            temp.addr =newNode
            newNode.addr =self.head
            
    def insert_at_first(self,val):
        newNode =Node(val)
        if self.head is None:
            self.head = newNode
            newNode.addr =newNode
        else:
            temp =self.head
            while temp.addr != self.head:
                temp= temp.addr
            temp.addr =newNode
            newNode.addr =self.head
            self.head =newNode 
    def insert_at_loc(self,val,loc):
        newNode = Node(val)
        if loc <=0:
            print("enter loc above 0")
        elif loc == 1:
            self.insert_at_first(val)
        elif loc ==self.length()+1:
            self.insert_At_last(val)
        elif loc >self.length():
            print("enter location lessthan :",self.length())
        else:
            temp =self.head
            cnt =1
            while temp.addr != self.head and cnt <loc -1:
                temp =temp.addr
                cnt +=1  
            newNode.addr =temp.addr
            temp.addr =newNode
    def delete_at_last(self):
        if self.head is None:
            print("no nodes to delete")
        else:
            temp =self.head
            while temp.addr.addr !=self.head:
                temp =temp.addr
            temp.addr =self.head
            
    def delete_at_first(self):
        if self.head is None:
            print("no nodes to display")
        else:
            temp =self.head
            while temp.addr != self.head:
                temp=temp.addr
            temp.addr =self.head.addr   
            self.head =self.head.addr
    def delete_at_loc(self,loc):
        if loc <=0:
            print("enter the loc above 0")
        elif loc ==1:
            self.delete_at_first()
        # elif loc ==self.length():        NO NEED TO CHECK THIS CONDITION
        #     self.delete_at_last()
        elif loc >self.length():
            print("enter the location lessthan :", self.length())
        else:
            temp =self.head
            cnt =1
            while temp.addr !=self.head and cnt<loc-1:
                temp =temp.addr
                cnt += 1
            temp.addr =temp.addr.addr     
               
            
                                 
                    
    def display(self):
        if self.head is None:     
            print("No nodes to display")  
        else:
            temp =self.head
            while temp:   #till the time temp is not none 
                print(temp.data, end="->") #print the data present in the temp variable
                temp =temp.addr   #update the address of the temp 
                if temp == self.head:
                    break      
            print()    
    def length(self):
        if self.head is None:     
            print("No nodes to count")  
        else:
            temp =self.head
            cnt =0
            while temp:   #till the time temp is not none 
                cnt +=1
                temp =temp.addr   #update the address of the temp   
                if temp ==self.head:
                    break          
            return cnt     
        
        
cll =Circular_Linked_List()
cll.insert_at_last(20)
cll.insert_at_last(30)
cll.display()
print("toatl nodes in CLL is ",cll.length())
cll.insert_at_first('A')
cll.display()
print("toatl nodes in CLL is ",cll.length())  
cll.insert_at_loc('B',2)                                     
cll.display()
print("toatl nodes in CLL is ",cll.length())  
cll.delete_at_last()
cll.display()
print("toatl nodes in CLL is ",cll.length()) 
cll.delete_at_first()
cll.display()
print("toatl nodes in CLL is ",cll.length()) 
cll.insert_at_first('W')
cll.display()
print("toatl nodes in CLL is ",cll.length()) 
cll.insert_at_first('K')
cll.display()
print("toatl nodes in CLL is ",cll.length()) 
cll.delete_at_loc(2)
cll.display()
print("toatl nodes in CLL is ",cll.length())
# Out:
# 20->30->
# toatl nodes in CLL is  2
# A->20->30->
# toatl nodes in CLL is  3
# A->B->20->30->
# toatl nodes in CLL is  4
# A->B->20->
# toatl nodes in CLL is  3
# B->20->
# toatl nodes in CLL is  2
# W->B->20->
# toatl nodes in CLL is  3
# K->W->B->20->
# toatl nodes in CLL is  4
# K->B->20->
# toatl nodes in CLL is  3
