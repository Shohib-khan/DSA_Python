# %%
class Node:
    def __init__(self,data):
        self.data =data
        self.addr =None
        
class Single_Linked_List:
    def __init__(self):
        self.head =None
        
    def insert_At_last(self,val):
        newNode =Node(val)
        if self.head is None:
            self.head =newNode  #here if self.head is none than direclty we can insert the newNode at the last position
        else:
            temp =self.head    #putting self.head in temp variable
            while temp.addr !=None: # and till the time the address of the temp is not none
                temp =temp.addr  # put the address of the next node in the temp variable
            temp.addr =newNode # when address of the temp become none attach a new node at that place
    
    def display(self):
        if self.head is None:     
            print("No nodes to display")  
        else:
            temp =self.head
            while temp:   #till the time temp is not none 
                print(temp.data, end="->") #print the data present in the temp variable
                temp =temp.addr   #update the address of the temp 
                
    def length(self):
        if self.head is None:     
            print("No nodes to count")  
        else:
            temp =self.head
            cnt =0
            while temp:   #till the time temp is not none 
                cnt +=1
                temp =temp.addr   #update the address of the temp             
            return cnt
        
    def insert_at_first(self,val):
        newNode =Node(val)
        if self.head is Node:
            self.head = newNode
        else:
            newNode.addr =self.head
            self.head =newNode        
            
            
    def insert_at_loc(self,val,loc):
        newNode = Node(val)
        if loc <=0:
            print("enter loc above 0")
        elif loc == 1:
            self.insert_at_first(val)
        elif loc ==self.length()+1:
            self.insert_At_last(val)
        elif loc >self.length():
            print("enter location lessthan :",self.length())
        else:
            temp =self.head
            cnt =1
            while temp.addr != None and cnt <loc -1:
                temp =temp.addr
                cnt +=1
            newNode.addr =temp.addr
            temp.addr =newNode       
            
    def delete_at_last(self):
        if self.head is None:
            print("no nodes to delete")
        elif self.length()==1:
            self.head =None 
        else:
            temp =self.head
            while temp.addr.addr !=None:
                temp =temp.addr
            temp.addr =None   
            
    def delete_at_first(self):
        if self.head is None:
            print("no nodes to display")
        else:
            self.head =self.head.addr      
    
    def delete_at_loc(self,loc):
        if loc <=0:
            print("enter the loc above 0")
        elif loc ==1:
            self.delete_at_first()
        # elif loc ==self.length():        NO NEED TO CHECK THIS CONDITION
        #     self.delete_at_last()
        elif loc >self.length():
            print("enter the location lessthan :", self.length())
        else:
            temp =self.head
            cnt =1
            while temp.addr !=None and cnt<loc-1:
                temp =temp.addr
                cnt += 1
            temp.addr =temp.addr.addr
                
                                
                                     
s1 =Single_Linked_List()
while True:
    print("------Single Linked List Operations------")
    print("1.Insert at Last\n2.Insert at First\n3.Insert at Location\n4.Display\n5.Length\n6.Delete at Last\7.Delete at First\n8.Delete at Location")
    
    opt =int(input("enter the option"))
    match opt:
        case 1:
            val =input("enter the value :")
            s1.insert_At_last(val)
        case 2:
            val =input("enter the value :")
            s1.insert_at_first(val)
        case 3:
            val =input("enter the value :")
            loc =int(input("enter the location :"))
            s1.insert_at_loc(val.loc)
        case 4:
            s1.display()
        case 5:
            s1.length()
        case 6:
            s1.delete_at_last()
        case 7:
            s1.delete_at_first()
        case 8:
            loc =int(input("enter the location :"))
            s1.delete_at_loc(loc)
        case 9:
            break 
        case _:
            print("Invalid Option :")
# Out:
# ------Single Linked List Operations------
# 1.Insert at Last
# 2.Insert at First
# 3.Insert at Location
# 4.Display
# 5.Length
# 6.Delete at Last.Delete at First
# 8.Delete at Location
# ------Single Linked List Operations------
# 1.Insert at Last
# 2.Insert at First
# 3.Insert at Location
# 4.Display
# 5.Length
# 6.Delete at Last.Delete at First
# 8.Delete at Location
# 20->------Single Linked List Operations------
# 1.Insert at Last
# 2.Insert at First
# 3.Insert at Location
# 4.Display
# 5.Length
# 6.Delete at Last.Delete at First
# 8.Delete at Location
# ------Single Linked List Operations------
# 1.Insert at Last
# 2.Insert at First
# 3.Insert at Location
# 4.Display
# 5.Length
# 6.Delete at Last.Delete at First
# 8.Delete at Location
# Invalid Option :
# ------Single Linked List Operations------
# 1.Insert at Last
# 2.Insert at First
# 3.Insert at Location
# 4.Display
# 5.Length
# 6.Delete at Last.Delete at First
# 8.Delete at Location
# Invalid Option :
# ...
